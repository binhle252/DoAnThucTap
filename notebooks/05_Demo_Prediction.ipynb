# %% [markdown]
# # 05 - Demo Prediction
#
# Goal: predict whether one new traffic flow is benign or malicious.

# %%
from argparse import Namespace
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.demo_predict import predict_flow  # noqa: E402

print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Example flow
#
# You can change these values to test another traffic record.

# %%
args = Namespace(
    arrays_path=PROJECT_ROOT / "data" / "processed" / "graph_arrays.npz",
    node_mapping_path=PROJECT_ROOT / "data" / "processed" / "node_mapping.csv",
    preprocessor_path=PROJECT_ROOT / "data" / "processed" / "edge_preprocessor.joblib",
    model_path=PROJECT_ROOT / "models" / "gat_edge_classifier.pt",
    cpu=False,
    ts=1536227023.384673,
    src_ip="192.168.100.111",
    src_port=17576.0,
    dst_ip="78.1.220.212",
    dst_port=8081.0,
    proto="tcp",
    service="missing",
    duration=0.000003,
    orig_bytes=0.0,
    resp_bytes=0.0,
    conn_state="S0",
    missed_bytes=0.0,
    history="S",
    orig_pkts=2.0,
    orig_ip_bytes=80.0,
    resp_pkts=0.0,
    resp_ip_bytes=0.0,
)

result = predict_flow(args)
result
