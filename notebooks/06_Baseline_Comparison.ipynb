# %% [markdown]
# # 06 - Baseline Comparison
#
# Goal: compare GAT with graphless baseline models on the same graph edge features and the same train/validation/test masks.
#
# This answers an important defense question: why use GAT, and how does it compare with classical machine learning?

# %%
from argparse import Namespace
from pathlib import Path
import sys

import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.train_baselines import train_baselines  # noqa: E402

print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Run baselines
#
# The baselines use `edge_attr` from `graph_arrays.npz`, so the comparison uses the same 100k edges as the GAT experiment.

# %%
args = Namespace(
    arrays_path=PROJECT_ROOT / "data" / "processed" / "graph_arrays.npz",
    model_dir=PROJECT_ROOT / "models",
    results_dir=PROJECT_ROOT / "results",
    random_state=42,
)

results = train_baselines(args)
results["comparison_path"]

# %% [markdown]
# ## Compare models

# %%
comparison = pd.read_csv(PROJECT_ROOT / "results" / "model_comparison.csv")
comparison

# %% [markdown]
# ## Interpretation
#
# If a classical baseline such as Random Forest is nearly perfect, the current random split is probably easy. This is useful evidence that the next essential extension should be a stricter split, such as time-based split or unseen-IP split.
